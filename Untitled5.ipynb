# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
stopwords = ['want','has','.689','jxu@black.clarku.edu','thf2@kimbark.uchicago.edu','Oscar','.','Rangers?','Perez.','Smith.','AAA.',
             'AAA)','AAA,','>Lupica','Chunichi','camelot.bradley.edu','kahn@troi.cc.rochester.edu','Charlie','Richmond','had','M.',
             '<C5qGLD.Dut@cc.swarthmore.edu>,','Col,bichette','4.5','Senators','Graca)','30332','*Atlanta','Then','They','Daryl',
             '<1993Apr6.203330.4974@oucsace.cs.ohiou.edu>','"To','275','274','27.','(except','1997.','"Mark','lots','Jays','Aaron',
             '-----------oOO--(_)--OOo-----------','Chicago','Maybe','cogsci.ucsd.edu','Anderson','Hi,','stwombly@cs.ulowell.edu',
             'taurus.meaddata.com','Smith)','Smith,','MLEs.','His','Abbott','Redding','(Well,','Mil,gvaughn','La','CF.','Bosio',
             '.681','.680','17:31:58','.575','.574','.577','.570','.576','.571','.573','.578','Kittys','L.','ronc@vnet.ibm.com',
             'LP','LH','LO','LA','Jacobs.','Jacobs)','LF','(D.','CF,','Cle,hill','Lu','>Oh,','VNEWS','Le','h','therefore','Year-Buck',
             'Gopher)','Galarraga','"The','Harvey','WINCO','>Doug','AT&T','Hamilton','Cin,sabo','Keach','molest.ugcs.caltech.edu',
             '>Pat','Western','repairs********************************','Valle','Lajoie','Hou,bagwell', 'much','Those','Dopson',
             '<1993Apr20.165738.16495@mnemosyne.cs.du.edu>','Braves-Giants','.726','whoever','dietz@parody.Data-IO.COM','Rauser',
             'ravel.udel.edu','g215a-1.nextwork.rose-hulman.edu','Dykstra','Lasorda','.685','0.672','Lurie','Rangers.','Rangers,',
             '<1993Apr5.123904.17806@porthos.cc.bellcore.com>',"Olson's",'Steven','>7)''rstimets@silver.ucs.indiana.edu','one',
             'Lopez','My','ME','MD','MF','MA','MB','MM','ML','MN','MI','Elias',"couldn't",'with','NY','Owen.','Michigan','.253',
             '.252','.251','.250','.257','.256','.255','.254','.259','Rodriguez,','<34592@oasys.dt.navy.mil>','Thornton',
             '.....................................................................','<1993Apr19.024222.11181@newshub.ariel.yorku.ca>'
             '++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++','aardvark@spica.la.locus.com','did','Huckabay',
             'acad.drake.edu','Finley','<C5wEwD.Kto@murdoch.acc.Virginia.EDU>','yajima@nttcom.ntt.jp', 'the', 'nntp posting host',
             'posting host', '"who', '.688', 'ra.1993Apr6.173224.13148', 'CFs', 'Smith"', '17.18', 'Marks', 'ddsokol@unix.amherst.edu'
             '<1993Apr19.024222.11181@newshub.ariel.yorku.ca>', 'the', 'to', 'of', 'and', 'in', 'that', 'is', 'he', 'edu', 'it',
             'you', 'for', 'have', 'was', 'this', 'be', 'not', 'as', 'on', 'they', 'but', 'com', 'if', 'his', 'are', 'at', 'or',
             'from', 'nntp', 'nntp posting', 'would', 'can', 'up', 'more', 'article', 're', 'posting host', 'don', 'than', 
             'so', 'cs', 'will', 'about', 'we', 'who', 'all', 'there', 'no', 'what', 'been', 'subject', 'even', '12', 'an',
             'good', 'time', 'him', 'when', 'morris', 'those', 'get', 'roger', 'how', 'by', 'over', 'anyone', 'should', 
             'hirschbeck', 'could', 'braves', 'do', 'think', 'know', 'come', 'jewish', 'lafayette', 'lafibm', 'vb30', 
             'lafayette vb30', 'posting host', 'very', 'sabo', 'sure', "can't", 'me', 'also', 'three', 'writes', 'any', 
             'like', 'ibm', 'aix', 'posting host', 'your', 'see', 'kingston', 'host', '00', 'many', 'only', 'why', 'better',
             'because', 'now', 'might', 'their', 'gant', 'too', 'way', '03', 'david', 'mike', '02', '04', 'my', 'duke', 
             'still', 'well', '04', 'around', 'big', 'michael', 'cc', 'probably', 'here', 'just', 'after', 'netcom', 'these',
             'really', '10']
wordDict = dict()
wordSet = []

# %%
for c in corpus:
    text = c.encode('utf8')
    text = str.split(text)
    for t in text:
        if t in stopwords:
            continue
        elif t in wordSet:
            wordDict[t] += 1
        else:
            wordSet.append(t)
            wordDict[t] = 1
wordDict
# Out:
# {'Fame.': 5,
#  'considered,': 1,
#  'Fame,': 4,
#  'Cow."': 1,
#  'cords,': 1,
#  '*best*': 2,
#  'Fame?': 3,
#  'hanging': 2,
#  'localized': 1,
#  'nature).': 1,
#  'bringing': 8,
#  'wooden': 2,
#  'Oddly,': 1,
#  'stereotypical': 1,
#  'mailing.': 1,
#  '278': 4,
#  '279': 1,
#  'errors': 8,
#  'cooking': 2,
#  'candidates,': 2,
#  '39RBI,': 1,
#  '>Most': 4,
#  'outfielders': 6,
#  'kid)': 1,
#  'kid.': 1,
#  '>last': 4,
#  '.3%.': 1,
#  'kidding...just': 1,
#  'crouch': 2,
#  'Foundation': 4,
#  'fire,': 1,
#  'Hrm.': 2,
#  'affiliated': 1,
#  'chink': 1,
#  'kids': 8,
#  'outfielder,': 4,
#  'outfielder.': 3,
#  'climbed': 1,
#  'outfielder)': 1,
#  'error,': 3,
#  'error.': 7,
#  'golden': 1,
#  '>>statistical': 1,
#  'projection': 2,
#  'Naked.': 1,
#  'population,': 2,
#  '>>strong': 1,
#  'population.': 4,
#  'Indeed,': 3,
#  'abbreviations': 3,
#  'Indeed!': 1,
#  'music': 7,
#  '>shaky)': 1,
#  'ability.': 7,
#  '0.675': 1,
#  '0.677': 1,
#  'show.': 3,
#  'circumstances': 1,
#  '(many': 1,
#  'locked': 1,
#  'liability,': 2,
#  'liability.': 4,
#  '"Southpaw"?': 1,
#  'locker': 3,
#  'catch.': 9,
#  'facade': 1,
#  '>across': 1,
#  'absolute': 5,
#  'travel': 2,
#  'Attention': 1,
#  'copious': 2,
#  '>>successfuls': 1,
#  'honored': 1,
#  '>>Carter,': 1,
#  'wrong': 22,
#  '18th': 1,
#  'nonsensical': 1,
#  '>neither': 1,
#  'effect.': 1,
#  'Wills': 1,
#  'effect?': 1,
#  'rewarded': 2,
#  'activating': 2,
#  'Hit': 1,
#  'fit': 18,
#  'fix': 2,
#  'conclusion,': 3,
#  'Boswaukta': 1,
#  'welcome.': 1,
#  '>>>Just': 1,
#  '"win"': 1,
#  'Will,': 1,
#  'Alou': 1,
#  'Smith?': 1,
#  'GEESH.': 1,
#  '>Earned': 1,
#  'Abbot,': 1,
#  'Hi-': 1,
#  'basehits,': 1,
#  'master.1psqpdINNh9v': 1,
#  'correct.': 4,
#  'correct,': 1,
#  '39.': 2,
#  '39,': 1,
#  '395': 1,
#  '394': 1,
#  'correct?': 3,
#  '398': 1,
#  'Karkovice': 1,
#  '0-162': 1,
#  'simpler.': 1,
#  '(Need': 1,
#  'encourage': 3,
#  'noice': 1,
#  'zap': 1,
#  'compete,': 1,
#  'outburst': 1,
#  'abbott': 1,
#  '04473': 1,
#  '>[All': 1,
#  'Casburn)': 1,
#  'estimate': 1,
#  'universally': 1,
#  'tell,': 2,
#  '(210)533-8318': 1,
#  'disturbed': 2,
#  'Peterson)': 1,
#  '>>>(Look': 1,
#  '"happened': 2,
#  'guys?': 2,
#  'reward!': 1,
#  '(spelling': 1,
#  'comment?)': 2,
#  '"Boneshead",': 1,
#  'diligently': 1,
#  'renovated': 1,
#  'service': 9,
#  'needed': 17,
#  'master': 2,
#  'salaries.)': 1,
#  'College,': 10,
#  'alleg.1993Apr6.205911.2654': 1,
#  '"sitting': 1,
#  '*now*,': 1,
#  'dak988s@vma.smsu.edu': 1,
#  '>>_My_': 1,
#  'feeling': 15,
#  'old,': 3,
#  'old.': 3,
#  'spectrum': 2,
#  '>-Craig': 1,
#  'dozen': 7,
#  '2.79': 1,
#  'sh*t.': 1,
#  'long?': 2,
#  'english.': 1,
#  'simplify': 1,
#  'mouth': 1,
#  'long.': 14,
#  'long,': 7,
#  'field).': 1,
#  'Casburn': 1,
#  'saying': 55,
#  '.300!': 1,
#  'damaged.': 1,
#  'padded': 2,
#  'bonuses': 2,
#  'rick': 1,
#  '>>>bob': 1,
#  'plate': 42,
#  'Kessinger': 1,
#  'frankly,': 4,
#  "List's": 1,
#  'waaaaaay': 1,
#  'Perez?': 2,
#  'altogether': 1,
#  'Mark?': 1,
#  'Fascinating': 1,
#  'nicely': 7,
#  '1992-93': 1,
#  'patch': 3,
#  '_NAILS_': 1,
#  'bet...': 1,
#  'run-value': 1,
#  'Hrm?': 2,
#  '196.2': 1,
#  '196.0': 1,
#  'Astonomicals': 1,
#  '>california': 1,
#  'usenet.C51vwC.Lru': 1,
#  'Munoz': 1,
#  'Advanced': 3,
#  'involved.': 5,
#  'extend': 1,
#  'nature': 1,
#  'seriously.': 3,
#  'extent': 7,
#  'gwyn': 1,
#  'Bronx': 3,
#  'UNTIL': 1,
#  'lot:': 2,
#  '"No,': 2,
#  'BillLee': 1,
#  '>>Sherri': 1,
#  'slug-bunt;': 1,
#  'lot.': 15,
#  'lot,': 10,
#  'directly)': 1,
#  'directly,': 1,
#  'playmates:': 1,
#  'Ack-people': 3,
#  'doubt,': 5,
#  'gopher': 2,
#  'cuz': 5,
#  "Clinton's": 1,
#  'GRN': 1,
#  'doubt?': 1,
#  'Astro': 1,
#  "baseman's": 4,
#  'nap...': 1,
#  'bothers': 1,
#  '"one': 1,
#  'pinch-running': 1,
#  'spit': 2,
#  'credited,': 2,
#  'dave': 2,
#  'doubts': 2,
#  'Fielding,': 2,
#  'Year-Eric': 1,
#  'Beware': 1,
#  'bother.': 1,
#  'employ': 1,
#  'fun.n': 1,
#  '...!{decvax,hplabs,ncar,purdue,rutgers}!gatech!prism!mm36': 1,
#  '<ag4i+@andrew.cmu.edu>': 1,
#  '0.077': 1,
#  'consent.': 2,
#  '*precisely*': 1,
#  '0.070': 1,
#  'south,': 1,
#  '(46/39)': 1,
#  '>>which': 1,
#  '13.15': 1,
#  'Valley': 1,
#  'McWeekly):': 1,
#  'denied".': 1,
#  '/____________': 1,
#  'Errey': 1,
#  '>>has': 1,
#  "Rangers'": 1,
#  'academic': 3,
#  'outfielder:': 4,
#  'SFWA': 3,
#  '$900K.': 1,
#  'losers.': 5,
#  'GREATS': 6,
#  'tennant.': 1,
#  'Laureate': 1,
#  '????': 2,
#  '"Majors".': 1,
#  'Stuart.': 1,
#  'Happy': 1,
#  'Harlem': 1,
#  '>hitting.': 1,
#  'out-of-town': 2,
#  'ego-ectomy': 1,
#  'advancement': 1,
#  'Undeserving': 1,
#  'hat': 1,
#  'taxes:': 2,
#  '>won/lost': 1,
#  'network...': 1,
#  '>7,': 2,
#  '*hoping*': 1,
#  '>7.': 3,
#  'hpisq3lk.cup.hp.com': 1,
#  '>7)': 3,
#  '++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++': 2,
#  '-Imus': 2,
#  'Rawley': 1,
#  '>Last': 9,
#  'won?': 1,
#  'T--2:12.': 1,
#  'ha,': 1,
#  '>adjusting': 1,
#  'Hey!': 1,
#  'Swedish': 1,
#  'crowd': 12,
#  'crown': 1,
#  'topping': 1,
#  'Between': 4,
#  '>*never*': 1,
#  '<1993Apr20.033504.13966@mnemosyne.cs.du.edu>,': 1,
#  'news.12799': 1,
#  'bottom': 24,
#  'Eagles.': 4,
#  'opponents': 3,
#  'Schu,': 1,
#  "Eagles'": 3,
#  'wittsend!gisatl!deitch': 1,
#  'amhux3.amherst.edu': 1,
#  'Slugging?': 1,
#  'Mathews"!': 1,
#  'Morgan-Castillo-Guzman-Hibbard': 1,
#  'benches': 2,
#  'browse': 4,
#  'benched': 4,
#  'Fredericks': 3,
#  '(surprise)': 1,
#  'Incidentally,': 5,
#  '00ECGILLESPIE': 2,
#  'Limited.': 1,
#  'due.': 4,
#  'Jay)': 1,
#  'approx.': 1,
#  'spraining': 1,
#  'humble,': 1,
#  '>>total': 1,
#  'raped': 1,
#  'Jay?': 1,
#  'revenues.': 1,
#  'Pit,merced': 1,
#  'Fielder.': 4,
#  'Boudreau': 2,
#  '>/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\': 1,
#  '1B)': 1,
#  '1B,': 3,
#  '1958.': 1,
#  'duel': 1,
#  'onions,': 1,
#  "else's": 3,
#  '(15-4)': 1,
#  'County': 4,
#  'smashed': 1,
#  '(Kent': 4,
#  '>Koufax,': 1,
#  '>requested.': 1,
#  'ddsokol@unix.amherst.edu': 2,
#  'DAWSON': 1,
#  '(kinda': 1,
#  'signature),': 1,
#  'minds.': 1,
#  'minds,': 1,
#  '.728': 2,
#  'role': 17,
#  'temporarily,': 1,
#  '.727': 1,
#  'roll': 1,
#  'rec.sport.baseball.graffiti,': 2,
#  'Cabaniss......................*Wait': 1,
#  'intend': 5,
#  'Chicago...': 1,
#  'devon': 1,
#  '34-': 1,
#  'variable': 1,
#  '>average': 3,
#  'explosions': 1,
#  "barrym@informix.com's": 1,
#  '(Offensive': 2,
#  'smithers@dcseq.uscga.edu': 1,
#  'Smith);': 1,
#  'netnews.120665': 1,
#  'reversible': 1,
#  'IRONMAN': 1,
#  'corps': 2,
#  'stay,': 1,
#  'stay.': 1,
#  '[Too': 1,
#  'profits.': 1,
#  '"after': 1,
#  'ORIOLE': 1,
#  'Trillo': 1,
#  'magazines,': 1,
#  '(Shannon': 1,
#  'tomorrow...': 1,
#  '*across*': 1,
#  'Schuerholz/Cox': 1,
#  'losing.': 1,
#  'macho': 1,
#  'jerk': 1,
#  'Rodriguez.': 1,
#  'choice': 15,
#  'Lyle': 1,
#  'stays': 3,
#  'exact': 10,
#  'minute': 8,
#  'Fortunately,': 1,
#  'Organized': 1,
#  'nastness': 1,
#  'righties': 3,
#  'rec': 7,
#  'Date:': 2,
#  'chopping': 1,
#  'shirts': 1,
#  '>basis?': 1,
#  'pools,': 3,
#  'bagging': 1,
#  'pep': 2,
#  'Col,boston': 1,
#  "up,''": 1,
#  '23-foot': 1,
#  'boost': 4,
#  'may....': 1,
#  'dust.': 1,
#  'Me': 4,
#  'drafted': 1,
#  'Ma': 2,
#  'oldies': 1,
#  'Mo': 7,
#  'rickert@nextwork.rose-hulman': 1,
#  'trail)': 1,
#  '306': 1,
#  'address': 20,
#  'Cline,': 1,
#  '>>CF': 1,
#  '3B--MCKEAN.': 1,
#  'accomplished': 2,
#  'Ballparks': 1,
#  'MP': 2,
#  'MS': 1,
#  'MY': 3,
#  '(1987?': 1,
#  'REAL': 6,
#  'umps': 10,
#  'Double,': 1,
#  '17th,': 2,
#  '17th.': 1,
#  'Phi,pitcher': 1,
#  'cheering,': 1,
#  'public.': 3,
#  'Enough': 2,
#  'RILES': 1,
#  'be.)': 1,
#  'six-hitter,': 1,
#  'August': 3,
#  'working': 16,
#  '.500+': 1,
#  '.500,': 3,
#  '.500.': 2,
#  'opposed': 8,
#  '.500;': 1,
#  '(Also,': 1,
#  'Famers': 8,
#  'ump?': 1,
#  'random.': 4,
#  'Henley': 4,
#  '(using': 2,
#  'ump.': 1,
#  'ump,': 1,
#  'maneuver': 1,
#  'ump)': 1,
#  'fastball?"--': 1,
#  'originally': 4,
#  'Dilone': 1,
#  'following': 29,
#  'admired': 1,
#  'mentality': 1,
#  'parking,': 1,
#  ':>that': 1,
#  'heard,': 1,
#  "Lopez's": 4,
#  'lbr@holos.atl.ga.usa': 2,
#  'ST.': 1,
#  '3rd-base/LF': 1,
#  'First,"': 1,
#  '"there\'s': 1,
#  '"400': 1,
#  'Corporate': 8,
#  'brainless': 1,
#  'LEAGUE': 21,
#  'surfing': 2,
#  'Needless': 2,
#  'name-calling': 1,
#  '(66/58)': 1,
#  'doom.': 1,
#  'pulled': 7,
#  '(375/410/385': 2,
#  '2)Pat': 1,
#  '60s."': 2,
#  'anyone???????': 1,
#  'below)': 2,
#  'rstimets@silver.ucs.indiana.edu': 6,
#  'years': 135,
#  'professors': 1,
#  'Wickander': 1,
#  'boy!': 1,
#  'did!': 2,
#  'did,': 6,
#  'Cypress': 2,
#  'did.': 19,
#  'troubles': 1,
#  'dead.': 1,
#  'dead,': 1,
#  'suspension': 2,
#  'did?': 3,
#  '>valuable': 1,
#  'did;': 1,
#  'year?': 24,
#  'year:': 5,
#  'year;': 4,
#  'ego-boosting': 1,
#  '>>ump.': 1,
#  'year,': 109,
#  'year.': 181,
#  'Phily.': 1,
#  'year)': 9,
#  'year*': 2,
#  'year!': 1,
#  'trouble:': 1,
#  '>winning.': 1,
#  '>principal': 1,
#  '24.3': 1,
#  'trouble.': 2,
#  'Biancalana]': 1,
#  'trouble,': 1,
#  '(Rickey': 3,
#  'Anthrax': 1,
#  'trouble!': 2,
#  'entering': 2,
#  'curve?': 4,
#  'right.)': 1,
#  '797': 1,
#  'briefly,': 1,
#  'poseidon.athena.com': 1,
#  '>Phillies': 2,
#  'seriously': 9,
#  '(Maria': 1,
#  '<U31851@uicvm.uic.edu>': 1,
#  'catagory': 1,
#  '(?)': 2,
#  'disaster.': 1,
#  'workday,': 2,
#  '_They': 1,
#  '<1993Apr19.160012.24850@sni.ca>': 1,
#  '(nee': 1,
#  '.674': 2,
#  '>>>>expected': 1,
#  'modest': 1,
#  'benching': 1,
#  'specifications.': 2,
#  'quibble': 1,
#  '(includes': 1,
#  'Homeruns': 12,
#  "couldn't.": 3,
#  "couldn't,": 2,
#  'saving': 4,
#  'anymore.': 9,
#  '75-87.': 1,
#  'anymore,': 3,
#  'spoken': 1,
#  'Associates,': 1,
#  'anymore;': 1,
#  'Comiskey.': 2,
#  'Since:': 1,
#  'Monday': 8,
#  '1.53': 1,
#  'MVP!!': 1,
#  'Admittedly,': 2,
#  '>Canseco-is-lazy': 1,
#  'on-base': 1,
#  'IGGLES(Philadelphia': 1,
#  '<1qkkodINN5f5@jhunix.hcf.jhu.edu>,': 1,
#  'on.': 13,
#  'on,': 10,
#  'on!': 2,
#  "`n'": 1,
#  'on:': 2,
#  'on?': 3,
#  'History': 1,
#  '1.59': 1,
#  'bathead': 2,
#  '(12-12)': 1,
#  'so-so': 1,
#  'future.)': 1,
#  'high-scoring': 2,
#  '<1993Apr16.011653.7403@Princeton.EDU>': 1,
#  'turned': 21,
#  'Fletcher.': 1,
#  'Field': 8,
#  'Fletcher,': 1,
#  'turner': 1,
#  '(estimated)': 3,
#  'fashionable': 3,
#  '>early?': 1,
#  'intends': 1,
#  '>>8.': 1,
#  'corrections,': 1,
#  'Hall': 72,
#  'opposite': 3,
#  'discerning': 6,
#  'location.': 2,
#  'Allison': 1,
#  'location,': 1,
#  'printed': 7,
#  'tremendously.': 1,
#  'MAILING': 1,
#  'ointment.': 1,
#  'Chet': 1,
#  'Chef': 1,
#  'Anyways,': 2,
#  'stats....': 4,
#  'lazy.': 3,
#  'Schilling': 1,
#  'portent?': 1,
#  'inconsistent': 1,
#  'stadiums,': 1,
#  'objectively,': 1,
#  'overeagerness': 1,
#  '>Pendleton,': 1,
#  'effect,': 1,
#  'Enjoy,': 1,
#  'Pinella': 1,
#  'imagine.': 1,
#  'Exhibit': 1,
#  'the...': 1,
#  'press?': 1,
#  'ouch.': 1,
#  "could've": 1,
#  '*dump*.': 1,
#  "'em,": 1,
#  'vision': 1,
#  '>defensive': 2,
#  'award.': 1,
#  'punt.': 1,
#  '.875': 2,
#  'PITCHERS': 2,
#  'Phone:': 2,
#  'defensively': 14,
#  '|no': 2,
#  'Brekke--': 1,
#  'Inc.,': 9,
#  'High-End': 18,
#  'alarming': 1,
#  'Designated': 2,
#  '>September': 1,
#  "40's.": 1,
#  'enjoys': 3,
#  '>spot': 1,
#  'impression,': 1,
#  '*now*': 1,
#  'awards': 1,
#  'baseballs!"': 2,
#  '>Enlightenment': 1,
#  'Cosmos': 1,
#  '>>more': 1,
#  'Hathaway': 1,
#  'moon,': 1,
#  's': 9,
#  'sponsored.': 1,
#  '"for': 1,
#  'sponsored"': 1,
#  'Yankovic': 1,
#  '<1993Apr23.200913.6611@island.COM>': 1,
#  'reading.': 2,
#  'want.': 1,
#  '>all': 4,
#  'Address:': 10,
#  'pittance.': 1,
#  'Conine': 3,
#  'west': 1,
#  'pittance"': 1,
#  'collided': 1,
#  'Hammond?': 1,
#  '<1993Apr15.162313.154828@ns1.cc.lehigh.edu>': 1,
#  'wants': 16,
#  'aa649@Freenet.carleton.ca': 2,
#  "Berman's": 1,
#  '<186209@pyramid.pyramid.com>,': 1,
#  'Bob,': 2,
#  'extant': 1,
#  'former': 7,
#  'Adjusted': 3,
#  '"There\'s': 2,
#  'Vet.': 1,
#  'Vet,': 2,
#  'felonies,': 1,
#  'squeezed': 1,
#  'situation': 26,
#  'Hammonds': 1,
#  'edge,': 1,
#  'edge.': 1,
#  'kshus@schunix.uucp': 1,
#  'management,': 2,
#  'Admiral': 3,
#  'edge?': 4,
#  '<1993Apr19.024222.11181@newshub.ariel.yorku.ca>': 8,
#  '778-2546': 1,
#  '"rather': 1,
#  'Kiki': 1,
#  "Sandberg's": 2,
#  'deflate': 2,
#  'Anywhere': 1,
#  '_is_': 2,
#  'Cin,sanders': 1,
#  '"I"s...': 1,
#  'Mon,laker': 1,
#  'tracking': 1,
#  '>>Finally,': 1,
#  '(To': 3,
#  'nuisances,': 1,
#  'steaks,': 1,
#  'sharks-request@medraut.apple.com': 3,
#  'dimension': 1,
#  'effects': 2,
#  'BOX': 1,
#  'being': 165,
#  'Kamholz)': 1,
#  'nights?)': 1,
#  'BOB': 6,
#  'grounded': 2,
#  'grounder': 9,
#  'Assuming,': 1,
#  'Mae': 1,
#  '3-6):': 2,
#  'Student': 6,
#  'sums': 1,
#  'posts/day.': 1,
#  '>down': 2,
#  'sorry,': 11,
#  '.210,': 1,
#  'world': 78,
#  'Example': 2,
#  'sensational': 1,
#  'franchises,': 1,
#  '*equivalence*.': 1,
#  '(home': 1,
#  'superiority': 2,
#  'teach,': 1,
#  'seating': 3,
#  'KC!': 1,
#  'learning': 9,
#  'Bedrosian': 1,
#  'KC.': 2,
#  '46556': 1,
#  "'If": 1,
#  'diving': 1,
#  '(Judy': 1,
#  '*claim*': 1,
#  '91,': 2,
#  '91.': 1,
#  '"much': 2,
#  '916': 2,
#  'cliche,': 1,
#  'leadership': 7,
#  '<1993Apr19.194025.8967@adobe.com>,': 3,
#  'defense),': 1,
#  '(Jose': 1,
#  'LUMBERJACK': 2,
#  'Nigger': 1,
#  '.116': 1,
#  '.111': 3,
#  'division."': 1,
#  'cater': 1,
#  '10-year.': 2,
#  '.119': 1,
#  '>wagner@usc.edu': 1,
#  'No': 59,
#  '>Wow!': 1,
#  'reasons....he': 2,
#  'Cal,curtis': 1,
#  'pivot': 2,
#  'summaries,': 1,
#  'dirt,': 3,
#  'cared': 1,
#  'NJ': 6,
#  'ass.': 1,
#  'NL': 71,
#  'NN': 2,
#  'NO': 10,
#  'seasons;': 1,
#  'NC': 1,
#  'seasons?': 1,
#  'mindless': 3,
#  "seasons'": 1,
#  'back-to-back-to-back': 1,
#  'Mussina,': 8,
#  'seasons.': 7,
#  '>>Since': 2,
#  'seasons,': 13,
#  'NW': 6,
#  'N.': 5,
#  'parasites': 2,
#  'abused': 1,
#  'miss,': 2,
#  'rush': 4,
#  '[][]': 2,
#  '31.5': 1,
#  'dirty': 4,
#  '(25836-michael': 2,
#  'teams...': 2,
#  'trips': 7,
#  'IO20456@Maine.Maine.Edu': 6,
#  'three)': 1,
#  'expereienced': 1,
#  'gwieman@unl.edu': 1,
#  'Augie': 3,
#  'ensuing': 1,
#  '*HOUSTON*?': 1,
#  'UMass-Lowell': 3,
#  'attendance.': 1,
#  'RUNS': 1,
#  'SportsCenter': 1,
#  '(Danny': 1,
#  'Nicholson,': 2,
#  '<C5wtHC.9I2@world.std.com>': 1,
#  'trick.': 1,
#  'arm-twisting': 1,
#  'PETER': 1,
#  'Lady': 2,
#  "'Almost": 10,
#  'drafted,': 2,
#  'MVP,': 5,
#  'Path:': 1,
#  'Mexico.': 1,
#  '(57/17)': 1,
#  'RICKY': 2,
#  'waving': 5,
#  'speed.': 3,
#  'Pitch': 4,
#  'Moorhead': 1,
#  'finally,': 6,
#  "Francesa's": 2,
#  '(is': 1,
#  '(it': 2,
#  'maximum': 2,
#  'caused': 5,
#  '(613)': 6,
#  '10-3.': 2,
#  "McGriff's": 1,
#  '(in': 13,
#  'HRs,': 2,
#  '0.214': 9,
#  'norm': 1,
#  'adapt': 1,
#  'right-unbalanced': 1,
#  '"Eddie': 1,
#  'cause)': 1,
#  'problem!': 1,
#  'cleanup"?': 1,
#  'TIGHTER??': 1,
#  'sang': 2,
#  'Giants(?)': 1,
#  'small': 27,
#  'sank': 1,
#  'has,': 2,
#  'has.': 4,
#  'quicker': 1,
#  '199': 2,
#  '198': 2,
#  '195': 2,
#  '>Nieporents"': 1,
#  '190': 2,
#  '193': 1,
#  'past': 64,
#  'Department,': 4,
#  'traditional.': 2,
#  '19)': 1,
#  'displays': 1,
#  'pass': 3,
#  'IBB-Larkin': 1,
#  'investment': 1,
#  '"stopper"': 1,
#  'clock': 9,
#  "/'''": 1,
#  '(thanks': 1,
#  'twhite@mozart.amd.com': 1,
#  'full': 23,
#  'Abortion': 1,
#  "Steve's": 1,
#  'Spencer': 1,
#  'experience': 12,
#  'prior': 15,
#  'periodic': 1,
#  'benches,': 1,
#  'followed': 4,
#  'reclaimed': 1,
#  'Nuntius': 1,
#  'substance.': 1,
#  'attendance': 6,
#  '<1qn6tqINNmnf@senator-bedfellow.MIT.EDU>': 1,
#  '(Anton': 1,
#  'God.': 2,
#  ">>Nobody's": 1,
#  'God,': 1,
#  'cat-and-mouse': 1,
#  '0.951': 1,
#  'Apparently,': 1,
#  'company': 6,
#  'corrected': 3,
#  "Aren't": 2,
#  'Chad': 1,
#  '(early': 2,
#  '"all"': 1,
#  'learn': 12,
#  'knocked': 5,
#  '>Too': 1,
#  'catchers,': 6,
#  'huge': 12,
#  'respective': 6,
#  'players,': 38,
#  'ZERO.': 3,
#  'hugh': 1,
#  'dismissed': 1,
#  'purpose?"': 1,
#  'Tex,dascenzo': 1,
#  'hugs': 3,
#  'intended': 3,
#  'hit".': 1,
#  'spans.': 1,
#  'beenback': 2,
#  '695-9353/7395': 2,
#  'Disclaimer': 7,
#  'Desk:': 1,
#  "Hatcher's": 1,
#  '>>>himself': 1,
#  '"long': 1,
#  'replied': 3,
#  '>(by': 1,
#  'rant,': 2,
#  'paper': 14,
#  'scott': 12,
#  'replies': 1,
#  'smiling': 2,
#  'deleted..]': 1,
#  '>ing': 1,
#  'course.': 7,
#  'course,': 55,
#  'between,': 2,
#  'between.': 2,
#  '"lazy"?': 1,
#  'colleague': 2,
#  'availability?': 1,
#  'OPI:': 2,
#  'sign.': 1,
#  '<Apr.5.16.22.48.1993.11331@pilot.njin.net>': 3,
#  'Strathclyde': 1,
#  'sign?': 1,
#  '["Men': 1,
#  'everytime': 1,
#  '>23)': 1,
#  '|Not': 1,
#  'armchair': 1,
#  'minority,': 1,
#  '9.07': 1,
#  'sold.': 1,
#  'Steele)': 2,
#  'Kinerisms.': 1,
#  '(Toronto': 1,
#  'Surhoff': 3,
#  'bm562@cleveland.Freenet.Edu': 2,
#  '"lazy".': 1,
#  ';).': 1,
#  'Riggs': 1,
#  'research': 6,
#  'Report': 2,
#  'FIDO': 1,
#  'Prof.': 1,
#  'occurs': 4,
#  'talavage@sage.cc.purdue.edu': 2,
#  '<C09875D0@wuvmd.wustl.edu>': 1,
#  '>prove': 2,
#  "LET'S": 7,
#  '>Nolan': 2,
#  '10.70': 1,
#  'Leary,': 2,
#  'definition': 15,
#  'matured': 1,
#  '>Dibble': 1,
#  '3rd)': 2,
#  '3rd.': 2,
#  '3rd,': 4,
#  'Fri': 2,
#  'brutally': 2,
#  '>>Later,': 1,
#  'Fry': 1,
#  'laughable.': 1,
#  'YANKEES': 3,
#  'EASILY': 1,
#  'newsgroup..': 1,
#  '____|____====___H___________________====_====_====_': 2,
#  'nss3@midway.uchicago.edu': 1,
#  'first)': 1,
#  '.671.': 1,
#  'first,': 25,
#  '.219': 2,
#  'first.': 21,
#  'first!': 3,
#  'interviewed': 1,
#  'chose.).': 1,
#  'first;': 3,
#  'parsimonious': 1,
#  'first?': 4,
#  '29.9,': 1,
#  'interviewer': 1,
#  'Curtis?': 1,
#  'Cancer': 1,
#  'calculation,': 1,
#  '>future,': 1,
#  '>future.': 4,
#  '0.548': 2,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=stopwords, use_idf=True, ngram_range=(1,3))
X = vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x186155 sparse matrix of type '<type 'numpy.float64'>'
# 	with 212 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 49804)	0.0752473927837
#   (0, 185377)	0.0752473927837
#   (0, 28146)	0.0752473927837
#   (0, 143584)	0.0752473927837
#   (0, 131185)	0.0752473927837
#   (0, 100250)	0.0752473927837
#   (0, 64452)	0.0752473927837
#   (0, 110703)	0.0752473927837
#   (0, 160261)	0.0752473927837
#   (0, 116579)	0.0752473927837
#   (0, 62202)	0.0752473927837
#   (0, 100790)	0.0752473927837
#   (0, 131003)	0.0752473927837
#   (0, 140572)	0.0752473927837
#   (0, 95044)	0.0752473927837
#   (0, 111398)	0.0752473927837
#   (0, 162485)	0.0752473927837
#   (0, 58961)	0.0752473927837
#   (0, 49841)	0.0752473927837
#   (0, 35002)	0.0752473927837
#   (0, 62192)	0.0752473927837
#   (0, 49847)	0.0752473927837
#   (0, 64913)	0.0752473927837
#   (0, 49744)	0.0752473927837
#   (0, 85975)	0.0752473927837
#   :	:
#   (0, 32236)	0.0549377007686
#   (0, 20727)	0.0657361475295
#   (0, 81823)	0.0350629515641
#   (0, 140831)	0.0565465894589
#   (0, 118583)	0.113093178918
#   (0, 37014)	0.101411627943
#   (0, 39981)	0.107088035985
#   (0, 16450)	0.0752473927837
#   (0, 92293)	0.113093178918
#   (0, 6929)	0.0384423551904
#   (0, 97347)	0.0105002449772
#   (0, 160654)	0.0621721590323
#   (0, 46892)	0.0397486975651
#   (0, 172045)	0.0401025320285
#   (0, 110500)	0.0621721590323
#   (0, 172080)	0.0183766876548
#   (0, 156655)	0.0381398088748
#   (0, 28673)	0.0313625237113
#   (0, 117965)	0.0105213727517
#   (0, 66028)	0.127562095445
#   (0, 49727)	0.164813102306
#   (0, 37958)	0.0517503967441
#   (0, 37988)	0.0517503967441
#   (0, 96091)	0.0507058139713
#   (0, 182808)	0.0752473927837

# %%
X.shape
# Out:
# (994, 186155)

# %%
from sklearn.decomposition import TruncatedSVD
lsa = TruncatedSVD(n_components=20, n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=20, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01813399,  0.00214692,  0.00053472, ...,  0.00107109,
#         0.00107109,  0.00107109])

# %%
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_):
    termsInComp = zip(terms,comp)
    sortedTerms = sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print "Concept %d:" % i
    for term in sortedTerms:
        print term[0]
    print " "
# Out:
# Concept 0:
# year
# team
# game
# baseball
# games
# players
# out
# last
# organization
# lines
#
# Concept 1:
# season
# game
# games
# runs
# ll
# last year
# win
# year
# into
# base
#
# Concept 2:
# clutch
# team
# performance
# most
# back
# jhu
# league
# samuel
# best
# baseball players
#
# Concept 3:
# does
# say
# years
# last
# clutch
# year
# which
# league
# since
# york
#
# Concept 4:
# university
# ball
# them
# game
# base
# sox
# fans
# teams
# play
# players
#
# Concept 5:
# runs
# hit
# bob
# win
# most
# some
# maybe
# obp
# john
# run
#
# Concept 6:
# game
# baseball
# hitter
# best
# first
# am
# going
# back
# university
# news
#
# Concept 7:
# runs
# said
# people
# player
# players
# say
# baseball
# run
# team
# some
#
# Concept 8:
# game
# two
# first
# same
# games
# bonds
# most
# organization
# believe
# score
#
# Concept 9:
# team
# game
# year
# some
# pitching
# university
# which
# won
# make
# runs
#
# Concept 10:
# team
# pitching
# ve
# were
# win
# season
# play
# year
# years
# them
#
# Concept 11:
# years
# pretty
# am
# other
# since
# last
# go
# doesn
# university
# last year
#
# Concept 12:
# games
# team
# them
# year
# cubs
# does
# home
# steve
# runs
# batting
#
# Concept 13:
# university
# last
# am
# new
# hit
# games
# ll
# say
# going
# hitter
#
# Concept 14:
# university
# league
# years
# best
# ball
# lines
# some
# world
# baseball
# sox
#
# Concept 15:
# other
# make
# being
# distribution
# does
# before
# year
# world
# baseball
# series
#
# Concept 16:
# year
# players
# won
# mets
# other
# hit
# ca
# career
# let
# university
#
# Concept 17:
# game
# were
# league
# usa
# lines
# hit
# back
# season
# never
# frank
#
# Concept 18:
# some
# team
# were
# before
# mets
# where
# last
# game
# fans
# posting
#
# Concept 19:
# out
# some
# were
# distribution
# win
# being
# organization university
# back
# which
# sox
