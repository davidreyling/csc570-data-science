# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
M=nx.read_gml("polblogs.gml")

# %%
# create weighted graph from M
G = nx.Graph()
for u,v,data in M.edges_iter(data=True):
    if G.has_edge(u,v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# %% [markdown]
# ### 1.  Create a nice looking graph of the political blog network

# %% [markdown]
# ### 2.  What are the 10 most influential blogs?
#
# <li> dailykos.com<li>
# <li> talkingpointsmemo.com<li>
# <li> atrios.blogspot.com<li>
# <li> instapundit.com<li>
# <li> blogsforbush.com<li>
# <li> washingtonmonthly.com<li>
# <li> drudgereport.com<li>
# <li> powerlineblog.com<li>
# <li> michellemalking.com<li>
# <li> truthlaidbear.com<li>

# %% [markdown]
# ### 3.  What are the 10 least influential blogs?
#
# There are plenty with no edges whatsoever
# <li> richmar.blogspot.com <li>
# <li> estropundit.com <li>
# <li> truedemocrat.blogspot.com <li>
# <li> raincrossblog.com <li>
# <li> younglibs.com <li>
# <li> bradcarson.com/blog <li>
# <li> menaspirit.blogspot.com <li>
# <li> 95theses.blogspot.com <li>
# <li> eltcamerica.blogspot.com <li>
# <li> warriorscreed.000ke.com <li>

# %% [markdown]
# ### 4.  Answer this question for both left wing and right wing blogs seperately.  (Optional 10 Extra Credit Points)

# %%
plt.figure(figsize=(40,40))
pos=nx.spring_layout(G, iterations=500, scale=5, k=.3)
nx.draw_networkx_labels(G,pos, fontsize=8)
font = {'fontname' : 'Helvetica', 'color' : 'k', 'fontweight' : 'bold', 'fontsize' : 14}
plt.title("Network analysis", font)

nx.draw_networkx_nodes(G, pos, node_color='b', alpha=0.4)
nx.draw_networkx_edges(G, pos, alpha=0.4, node_size=0, width=1, edge_color='k')
plt.axis('off')
plt.show()
# Out:
# C:\Users\dreyl2\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family [u'Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
nx.write_gexf(G, 'ReylingNetwork.gexf')
